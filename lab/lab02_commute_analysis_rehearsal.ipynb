# %% [markdown]
# # Lab 2: Make a Transportation-Cost Recommendation
#
# **COMPSS 211A | Fall 2026 | Student copy**
#
# **Friday, September 18, 2026**
#
# Use Monday's filtering, functions, derived columns, and `groupby` ideas to answer a new question with synthetic commute records.

# %% [markdown]
# ## Today’s rhythm
#
# - **0–10 minutes:** Review Quiz 2.
# - **10–20 minutes:** Type along with a slow, five-line warm-up. Predict each result before running the line.
# - **20–47 minutes:** Complete four duo tasks. One person types and one explains; switch roles after Task 2. The instructor and GSI will check in as you work.
# - **47–50 minutes:** Give another pair a short spoken recommendation.
# - **50–60 minutes:** Take Quiz 3.
#
# This is a no-AI practice session. Use Monday's notebook, pandas documentation, your partner, and the teaching team. You do not need to hand in written answers.

# %% [markdown]
# ## The request
#
# A fictional campus transportation office has time for **one 30-minute listening session** this week. It wants to invite students from one of the four academic programs in this **synthetic** survey to talk about their monthly cost of getting to campus.
#
# Which program should it invite **first** if it starts with the group reporting the highest typical monthly transportation cost? Use the **median** cost among respondents who commute to campus, and say how many known costs support that median. The office will use the session to ask questions, not to decide funding or make claims about real Berkeley students.
#
# Before you recommend a program, inspect missing values and the overall 50th and 75th percentiles. Later, change one analysis choice to see whether your recommendation holds up.

# %% [markdown]
# ## Supplied setup
#
# Run this cell once. It loads the synthetic commute table and checks the course environment. We will not unpack the setup code today.

# %%
import platform
import sys
from pathlib import Path
import pandas as pd
import numpy as np

data_url = "https://raw.githubusercontent.com/macss-berkeley/compss-211a/9f4e28652fe776220d8470f03b681efddaf58192/data/hw1_after_dark_commute_survey.csv"
commute = pd.read_csv(data_url)

print("Python version:", platform.python_version())
print("Python 3.13:", platform.python_version().startswith("3.13."))
print("pandas version:", pd.__version__)
print("pandas matches 2.2.3:", pd.__version__ == "2.2.3")
print("NumPy version:", np.__version__)
print("NumPy matches 2.1.3:", np.__version__ == "2.1.3")
print("Python location:", sys.executable)
print("Working folder:", Path.cwd())
print("Rows and columns loaded:", commute.shape)

# %% [markdown]
# If an import fails or a version check says `False`, show the output to the instructor or GSI.
#
# ## Live-coding warm-up
#
# Type **one line per cell** while the instructor demonstrates it. Before running each line, predict what it will show. The 50% value in `.describe()` is the median; the 75% value is the upper quartile. These will help you interpret the program medians later.

# %% [markdown]
# Inspect `commute.columns`. Which column contains monthly transportation costs?

# %% [markdown]
# Select `program`, `commute_mode`, and `monthly_transport_cost_usd`, then show the first five rows.

# %% [markdown]
# Count missing values in `monthly_transport_cost_usd`.

# %% [markdown]
# Make `known_costs` from the cost column with `.dropna()`. Keep the original `commute` table unchanged.

# %% [markdown]
# Run `.describe()` on `known_costs`. Point out the 50% and 75% values to your partner.

# %% [markdown]
# ## Duo Task 1 · Decide who belongs in the comparison
#
# The office wants to ask about the cost of **getting to campus**. Remote respondents have recorded zero campus days and zero transportation costs. Those are real recorded zeros, but they do not describe a campus commute.
#
# Create `commuters` by keeping rows whose `commute_mode` is not `"Remote"`. Use `.copy()`. Then show:
#
# - how many rows remain and how many costs are missing;
# - `.describe()` for the nonremote costs, especially 50% and 75%; and
# - a few rows with `respondent_id`, `program`, `commute_mode`, and `monthly_transport_cost_usd`.
#
# Tell your partner why a missing cost should stay missing instead of becoming zero. **If you are stuck for two minutes, ask the teaching team to check your filter.**
#
# <details><summary>First hint</summary>Look at the `commute_mode` column and use `!= "Remote"` to keep other rows.</details>
#
# <details><summary>Next hint</summary>Try `commute[commute["commute_mode"] != "Remote"].copy()`. Use `.isna().sum()` to count unknown costs.</details>

# %% [markdown]
# ## Duo Task 2 · Create a useful category with a function
#
# Write `cost_band(cost)`. It must return:
#
# - `"unknown"` when the cost is missing;
# - one label for lower observed costs;
# - one label for middle observed costs; and
# - one label for higher observed costs.
#
# Choose and state two cutoffs. Test the function at both boundaries and on a missing value. Then use `.apply()` to create `commuters["cost_band"]` and display the category counts. Switch who types and who explains after this task. Tell your partner what the bands make easier to see and what exact amounts they hide.
#
# <details><summary>First hint</summary>Decide what to return for a missing value before you compare the cost with a number.</details>
#
# <details><summary>Next hint</summary>Start with `if pd.isna(cost): return "unknown"`, then use `if` and `return` for your two cutoffs. Ask the teaching team to check one boundary test if needed.</details>

# %% [markdown]
# ## Duo Task 3 · Compare academic programs
#
# Group `commuters` by `program`. Create `program_summary` with:
#
# - the number of respondents;
# - the number of known transportation costs; and
# - the median monthly transportation cost.
#
# Sort the largest median to the top. Which program leads, and how many known costs support it? Compare its median with the **50% and 75%** values you found for all commuters in Task 1. Is it above the overall middle cost? Is it above the upper quartile? Tell your partner why the respondent and known-cost counts can differ.
#
# <details><summary>First hint</summary>Use `.groupby("program")`; median ignores missing cost values.</details>
#
# <details><summary>Next hint</summary>Use `.agg(...)`. Count `respondent_id` for respondents and count the cost column for known costs. Sort by the median column with `ascending=False`.</details>

# %% [markdown]
# ## Duo Task 4 · Challenge the recommendation
#
# Change **one** analysis choice and recompute the comparison. Choose one:
#
# - use the mean instead of the median;
# - include remote respondents;
# - compare commute modes instead of programs; or
# - use your cost bands.
#
# Display the new result. Tell your partner what changed, and whether the original program recommendation still makes sense. It is fine if your new table answers a slightly different question.
#
# <details><summary>First hint</summary>Start from your Task 3 code and change just one part.</details>
#
# <details><summary>Next hint</summary>For the mean option, replace `"median"` with `"mean"` in your group summary and give the new result a new name.</details>

# %% [markdown]
# ## Share your recommendation aloud
#
# Give another pair a **one-minute explanation**. Say which program the fictional office should invite first, its median cost and known-cost count, and how that median compares with the overall 50th and 75th percentiles. Explain why you excluded remote respondents, kept missing costs unknown, and whether your changed analysis choice affected the result.
#
# Ask the other pair: **What would you want to learn in the listening session that this small synthetic table cannot tell you?** No written response is required.

# %% [markdown]
# ## Exit
#
# Save your notebook. The last 10 minutes are reserved for Quiz 3 on filtering, `groupby`, and derived columns.
